# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.shape
# Out:
# (1337, 7)

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df['sex'].value_counts()
# Out:
# sex
# male      675
# female    662
# Name: count, dtype: int64

# %%
dict_sex = {'male':1,'female':2}
dict_sex

# 1 for male
# 2 for female
# Out:
# {'male': 1, 'female': 2}

# %%
df['sex'] = df['sex'].map(dict_sex)
df.head()
# Out:
#    age  sex     bmi  children smoker     region      charges
# 0   19    2  27.900         0    yes  southwest  16884.92400
# 1   18    1  33.770         1     no  southeast   1725.55230
# 2   28    1  33.000         3     no  southeast   4449.46200
# 3   33    1  22.705         0     no  northwest  21984.47061
# 4   32    1  28.880         0     no  northwest   3866.85520

# %%
df['smoker'].value_counts()
# Out:
# smoker
# no     1063
# yes     274
# Name: count, dtype: int64

# %%
dict_smoker = {'yes':1,'no':0}
dict_smoker
# Out:
# {'yes': 1, 'no': 0}

# %%
df['smoker'] = df['smoker'].map(dict_smoker)
df.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19    2  27.900         0       1  southwest  16884.92400
# 1   18    1  33.770         1       0  southeast   1725.55230
# 2   28    1  33.000         3       0  southeast   4449.46200
# 3   33    1  22.705         0       0  northwest  21984.47061
# 4   32    1  28.880         0       0  northwest   3866.85520

# %%
df['region'].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    324
# northeast    324
# Name: count, dtype: int64

# %%
dict_region = {'northeast':1,'northwest':2,'southeast':3,'southwest':4}
dict_region
# Out:
# {'northeast': 1, 'northwest': 2, 'southeast': 3, 'southwest': 4}

# %%
df['region'] = df['region'].map(dict_region)
df.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    2  27.900         0       1       4  16884.92400
# 1   18    1  33.770         1       0       3   1725.55230
# 2   28    1  33.000         3       0       3   4449.46200
# 3   33    1  22.705         0       0       2  21984.47061
# 4   32    1  28.880         0       0       2   3866.85520

# %%
# all the columns are now numerical data columns

# %%
df.head(2)
# Out:
#    age  sex    bmi  children  smoker  region     charges
# 0   19    2  27.90         0       1       4  16884.9240
# 1   18    1  33.77         1       0       3   1725.5523

# %%
# determining x variables and y variable

x = df.drop('charges',axis=1)
y = df[['charges']]

# %%
y
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1337 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
# scikit-learn

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)
# 80% training size

# %%
from sklearn.linear_model import LinearRegression
# algorithm import

# %%
lnr = LinearRegression()

# %%
lnr.fit(x_train,y_train)   # model training
# Out:
# LinearRegression()

# %%
x_train.shape
# Out:
# (1069, 6)

# %%
x_train.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# dtype: int64

# %%
x_train
# Out:
#       age  sex     bmi  children  smoker  region
# 667    40    2  32.775         2       1       2
# 467    56    2  33.820         2       0       2
# 1205   35    1  17.860         1       0       2
# 498    44    2  23.980         2       0       3
# 968    21    1  25.745         2       0       1
# ...   ...  ...     ...       ...     ...     ...
# 719    58    2  33.440         0       0       2
# 301    53    2  22.610         3       1       1
# 934    32    1  37.180         2       0       3
# 57     18    1  31.680         2       1       3
# 956    54    1  30.800         1       1       3
#
# [1069 rows x 6 columns]

# %%
lnr.score(x_train,y_train)*100
# training score
# Out:
# 75.40914880582113

# %%
lnr.score(x_test,y_test)*100
# testing score
# Out:
# 73.43043789541588

# %%
# prediction
prediction = lnr.predict(x_test)

# %%
y_test
# original charges (not predicted charges)
# Out:
#           charges
# 1165   5227.98875
# 567    7256.72310
# 1050   8023.13545
# 898    1634.57340
# 703    5385.33790
# ...           ...
# 725   40932.42950
# 416    9140.95100
# 599   33471.97189
# 1181   2850.68375
# 773   17748.50620
#
# [268 rows x 1 columns]

# %%
y_test['prediction'] = prediction

# %%
y_test.head(30)
# Out:
#           charges    prediction
# 1165   5227.98875   5891.273913
# 567    7256.72310   9047.387043
# 1050   8023.13545  11819.324582
# 898    1634.57340   5445.064076
# 703    5385.33790   5726.331286
# 613    6753.03800   4171.445347
# 1090  41676.08110  35149.577781
# 1146  52590.82939  37195.622901
# 739   44585.45587  30459.775158
# 917   35069.37452  30843.826653
# 68     5920.10410   9934.726983
# 410    1621.34020  -1641.563533
# 505    6796.86325   8373.690407
# 496    4931.64700   3735.525568
# 966   23967.38305  33350.122025
# 1062  48970.24760  40233.894920
# 809    3309.79260   3255.144185
# 269    9282.48060   9604.506001
# 329    9144.56500  12802.478214
# 755    5031.26955   5723.941224
# 802    2103.08000    184.853476
# 762   19040.87600  28480.474074
# 16    10797.33620  12201.931840
# 757   23065.42070  32605.228688
# 1284  47403.88000  38895.774384
# 1159   3989.84100   9138.559390
# 44     6079.67150  10359.212944
# 885   19719.69470  29099.106603
# ...

# %%
import os, joblib

# %%
os.makedirs('models',exist_ok=True)  # models

# %%
lnr    
# this is our algorithm (or model)
# Out:
# LinearRegression()

# %%
joblib.dump(lnr,'./models/linear_model.lb')
# Out:
# ['./models/linear_model.lb']
